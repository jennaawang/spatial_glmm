# %%
from spatial_glmm_pkg import SpatialCustomLinkPQL, Poisson
import numpy as np

from scipy.special import expit, logit
from scipy.spatial.distance import cdist
from scipy.linalg import solve, cholesky, cho_solve, lstsq
from scipy.optimize import minimize
from scipy.stats import multivariate_normal

from sklearn.preprocessing import OneHotEncoder

import multiprocessing as mp
from functools import partial
import warnings, time

import matplotlib.pyplot as plt

# %%
n = 1000 
coords = np.random.uniform(0, 10, size=(n, 2))
dist_mat = cdist(coords, coords)

# Generate spatial random effect
true_sigma2 = 0.3
true_rho = 2.0

G_true = true_sigma2 * np.exp(-dist_mat / true_rho)
true_rand_fx = multivariate_normal.rvs(mean=np.zeros(n), cov=G_true)
print(np.mean(true_rand_fx))
true_rand_fx = true_rand_fx - np.mean(true_rand_fx)

# And expected tech effects
lin_prob_offset = -1.475
lin_prob = lin_prob_offset + true_rand_fx
true_tech = expit(lin_prob)

groups = np.random.choice(range(3), n).reshape(-1,1)

true_fixed_fx = np.array([np.log(40), np.log(20), np.log(55)])

ohe = OneHotEncoder(max_categories=3, sparse_output=False)
X = ohe.fit_transform(groups)

# Linear predictor
true_eta = X @ true_fixed_fx + np.log(expit(lin_prob_offset + true_rand_fx))
true_mu = np.exp(true_eta)

true_bio_means = np.exp(X @ true_fixed_fx)
# Generate observed counts
Y = np.random.poisson(true_mu)

init_beta=np.array([np.log(40), np.log(20), np.log(55)]) + 1.47

print(f"\nData summary:")
print(f"Y - mean: {np.mean(Y):.2f}, range: [{np.min(Y)}, {np.max(Y)}]")
print(f"mu - mean: {np.mean(true_mu):.2f}, range: [{np.min(true_mu):.2f}, {np.max(true_mu):.2f}]")
# Out:
# -0.03884386942215704
#
# Data summary:
# Y - mean: 7.45, range: [0, 39]
# mu - mean: 7.57, range: [1.03, 32.39]

# %%
model_pois = SpatialCustomLinkPQL(
    Y, X,
    a=-1.47,
    coords=coords,
    family=Poisson(),
    verbose=True
)

model_pois.fit(
    init_sigma2=0.2,
    init_rho=1,
    init_random=true_rand_fx,
    init_beta=np.log(np.array([4.99]*3)/0.2),
    damping=0.5,
    max_iter=150,
    update_var_components_every=1,
    tol=1e-5
)

model_pois.summary()
# Out:
# ======================================================================
# Spatial Poisson Custom Link PQL
# ======================================================================
# Observations: 1000
# Covariates: 3 (no intercept)
# Baseline 'a': mean=-1.470, std=0.000
# Baseline probability: 0.187
# Mean Y: 7.45
# Initial sigma2=0.2000, rho=1.0000
# Damping: 0.5
# ======================================================================
#
# Iter   1: beta=[3.542 3.119 3.802], sigma2=0.7195, rho=10.0000, b: [-1.123, 1.516], std(b)=0.518
# Iter   2: beta=[3.638 3.054 3.908], sigma2=0.8293, rho=10.0000, b: [-0.975, 1.398], std(b)=0.501
# Iter   3: beta=[3.678 3.016 3.953], sigma2=0.8446, rho=10.0000, b: [-0.932, 1.378], std(b)=0.498
# Iter   4: beta=[3.697 2.996 3.973], sigma2=0.8402, rho=10.0000, b: [-0.912, 1.372], std(b)=0.498
# Iter   5: beta=[3.706 2.985 3.983], sigma2=0.8357, rho=10.0000, b: [-0.903, 1.369], std(b)=0.498
# Iter   6: beta=[3.71  2.98  3.988], sigma2=0.8332, rho=10.0000, b: [-0.901, 1.368], std(b)=0.498
# Iter   7: beta=[3.712 2.977 3.99 ], sigma2=0.8320, rho=10.0000, b: [-0.900, 1.366], std(b)=0.498
# Iter   8: beta=[3.713 2.976 3.991], sigma2=0.8314, rho=10.0000, b: [-0.900, 1.366], std(b)=0.498
# Iter   9: beta=[3.714 2.975 3.992], sigma2=0.8312, rho=10.0000, b: [-0.900, 1.366], std(b)=0.498
# Iter  10: beta=[3.714 2.975 3.992], sigma2=0.8311, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  11: beta=[3.714 2.975 3.992], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  12: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  13: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  14: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  15: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  16: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
# Iter  17: beta=[3.714 2.974 3.993], sigma2=0.8310, rho=10.0000, b: [-0.899, 1.365], std(b)=0.498
#
# ======================================================================
# Converged in 17 iterations
# Final beta: [3.7145 2.9744 3.9926]
# Final b: mean=0.000000, std=0.4982
# Final sigma2=0.8310, rho=10.0000
# ======================================================================
#
#
# ======================================================================
# Spatial Poisson Custom Link GLMM
# ======================================================================
# Family: Poisson()
# Converged: True (in 17 iterations)
#
# Baseline 'a': -1.4700 (mean)
# Spatial variance: sigma2 = 0.8310
# Spatial range: rho = 10.0000
#
# Fixed effects (no intercept):
#   beta[0]: 3.7145
#   beta[1]: 2.9744
#   beta[2]: 3.9926
#
# Random effects:
#   mean: 0.000000 (should be ≈0)
#   std:  0.4982
#   range: [-0.8992, 1.3652]
#
# Fitted values:
#   mu: mean=7.45, range=[1.72, 25.68]
#   p:  mean=0.1983, range=[0.0856, 0.4738]
# ======================================================================
#
# Pearson dispersion: 0.8526

# %%
from spatial_glmm_pkg.plots import diagnostics, spatial_summary

# Four-panel GLM diagnostics (QQ, residuals vs fitted, scale-location, histogram)
diagnostics(model_pois)

# Six-panel spatial summary (observed, fitted, residuals, random effects, capture prob, QQ)
spatial_summary(model_pois)

# Individual plots
# from spatial_glmm_pkg.plots import qq_plot, plot_random_effects, plot_residuals_spatial
# qq_plot(model_pois, residual_type='deviance')
# plot_random_effects(model_pois)
# plot_residuals_spatial(model_pois, residual_type='pearson')
# Out:
# (<Figure size 1800x1000 with 11 Axes>,
#  array([[<Axes: title={'center': 'Observed Counts (Y)'}, xlabel='x', ylabel='y'>,
#          <Axes: title={'center': 'Fitted Values (μ)'}, xlabel='x', ylabel='y'>,
#          <Axes: title={'center': 'Spatial Residuals (Y - μ)'}, xlabel='x', ylabel='y'>],
#         [<Axes: title={'center': 'Random Effects (b)'}, xlabel='x', ylabel='y'>,
#          <Axes: title={'center': 'Capture Probability (p)'}, xlabel='x', ylabel='y'>,
#          <Axes: title={'center': 'QQ Plot (Pearson Residuals)'}, xlabel='Theoretical quantiles', ylabel='Pearson residuals'>]],
#        dtype=object))

# %%
from spatial_glmm_pkg import simulate_srt, SpatialCustomLinkPQL, Poisson

# Simulate
Y, X, coords, truth = simulate_srt(
    true_beta=np.log([40, 20, 55]),
    a=-1.47,
    sigma2=0.2,
    rho=1.0,
    n=1000,
    seed=42
)

# Check what was generated
print(f"Group means: {[Y[truth['group']==k].mean() for k in range(3)]}")
print(f"Capture rate: {truth['p'].mean():.3f}")

# Fit
model = SpatialCustomLinkPQL(Y, X, a=-1.47, coords=coords, family=Poisson())
model.fit(init_sigma2=0.2, init_rho=1.0, init_random=truth['b'],
          update_var_components_every=9999, damping=0.5)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from spatial_glmm_pkg import simulate_srt, SpatialCustomLinkPQL, Poisson
#       3 # Simulate
#       4 Y, X, coords, truth = simulate_srt(
#       5     true_beta=np.log([40, 20, 55]),
#       6     a=-1.47,
#    (...)
#      10     seed=42
#      11 )
#
# ImportError: cannot import name 'simulate_srt' from 'spatial_glmm_pkg' (/Users/jennawang/SURF_2026/spatial_glmm/spatial_glmm_pkg/__init__.py)
